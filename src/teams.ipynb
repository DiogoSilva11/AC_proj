# %%
#READ DATASET
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline

teams_data = pd.read_csv("../basketballPlayoffs/teams.csv")

# %%
# SIZE OF DATA
teams_data.shape
# Out:
# (142, 61)

# %%
# CHECK FOR DUPLICATED LINES
teams_data.duplicated().any()
# Out:
# False

# %%
# SEE THE FIRST ROWS
teams_data.head()
# Out:
#    year  lgID tmID franchID confID  divID  rank playoff  seeded firstRound  \
# 0     9  WNBA  ATL      ATL     EA    NaN     7       N       0        NaN
# 1    10  WNBA  ATL      ATL     EA    NaN     2       Y       0          L
# 2     1  WNBA  CHA      CHA     EA    NaN     8       N       0        NaN
# 3     2  WNBA  CHA      CHA     EA    NaN     4       Y       0          W
# 4     3  WNBA  CHA      CHA     EA    NaN     2       Y       0          L
#
#    ...  GP homeW homeL  awayW  awayL  confW  confL   min  attend  \
# 0  ...  34     1    16      3     14      2     18  6825  141379
# 1  ...  34    12     5      6     11     10     12  6950  120737
# 2  ...  32     5    11      3     13      5     16  6475   90963
# 3  ...  32    11     5      7      9     15      6  6500  105525
# 4  ...  32    11     5      7      9     12      9  6450  106670
#
#                 arena
# 0       Philips Arena
# 1       Philips Arena
# 2  Charlotte Coliseum
# 3  Charlotte Coliseum
# ...

# %%
# DESCRIPTION OF EACH ATTRIBUTE OF THE DATASET
teams_data.describe()
# Out:
#              year  divID        rank  seeded        o_fgm        o_fga  \
# count  142.000000    0.0  142.000000   142.0   142.000000   142.000000
# mean     5.302817    NaN    4.084507     0.0   860.387324  2039.683099
# std      2.917274    NaN    2.095226     0.0    86.998969   176.879707
# min      1.000000    NaN    1.000000     0.0   647.000000  1740.000000
# 25%      3.000000    NaN    2.000000     0.0   794.500000  1908.500000
# 50%      5.000000    NaN    4.000000     0.0   864.000000  2025.000000
# 75%      8.000000    NaN    6.000000     0.0   915.000000  2177.500000
# max     10.000000    NaN    8.000000     0.0  1128.000000  2485.000000
#
#             o_ftm       o_fta       o_3pm       o_3pa  ...        lost  \
# count  142.000000  142.000000  142.000000  142.000000  ...  142.000000
# mean   488.338028  651.366197  157.161972  463.014085  ...   16.661972
# std     70.749372   86.035246   43.736580  116.166119  ...    4.999131
# ...

# %%
# DESCRIPTION OF FUEL ATTRIBUTE OF THE DATASET
teams_data.describe(include='object')
# Out:
#         lgID tmID franchID confID playoff firstRound semis finals  \
# count    142  142      142    142     142         80    38     20
# unique     1   20       18      2       2          2     2      2
# top     WNBA  MIN      WAS     WE       Y          L     W      W
# freq     142   10       10     72      80         40    20     11
#
#                   name           arena
# count              142             142
# unique              20              22
# top     Minnesota Lynx  Verizon Center
# freq                10              10

# %%
# TYPES
teams_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142 entries, 0 to 141
# Data columns (total 61 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        142 non-null    int64
#  1   lgID        142 non-null    object
#  2   tmID        142 non-null    object
#  3   franchID    142 non-null    object
#  4   confID      142 non-null    object
#  5   divID       0 non-null      float64
#  6   rank        142 non-null    int64
#  7   playoff     142 non-null    object
#  8   seeded      142 non-null    int64
#  9   firstRound  80 non-null     object
#  10  semis       38 non-null     object
#  11  finals      20 non-null     object
#  12  name        142 non-null    object
#  13  o_fgm       142 non-null    int64
#  14  o_fga       142 non-null    int64
#  15  o_ftm       142 non-null    int64
#  16  o_fta       142 non-null    int64
#  17  o_3pm       142 non-null    int64
#  18  o_3pa       142 non-null    int64
# ...

# %%
# HEATHMAP SHOWING CORRELATION BETWEEN INGAME STATS
game_data = teams_data.drop(columns=['year', 'divID', 'seeded', 'tmORB', 'tmDRB', 'tmTRB', 'opptmORB', 'opptmDRB', 'opptmTRB'])
print(game_data.corr())
plt.subplots(figsize=(25,20))
sb.heatmap(game_data.corr(),annot=True)
# Out:
#             rank     o_fgm     o_fga     o_ftm     o_fta     o_3pm     o_3pa  \
# rank    1.000000 -0.339845 -0.128011 -0.230563 -0.163606 -0.117247 -0.052629
# o_fgm  -0.339845  1.000000  0.900705  0.609655  0.527834  0.397704  0.380516
# o_fga  -0.128011  0.900705  1.000000  0.596715  0.547350  0.423779  0.457988
# o_ftm  -0.230563  0.609655  0.596715  1.000000  0.933098  0.140181  0.142361
# o_fta  -0.163606  0.527834  0.547350  0.933098  1.000000 -0.011750 -0.006907
# o_3pm  -0.117247  0.397704  0.423779  0.140181 -0.011750  1.000000  0.970076
# o_3pa  -0.052629  0.380516  0.457988  0.142361 -0.006907  0.970076  1.000000
# o_oreb -0.053003  0.373241  0.537198  0.351655  0.464996 -0.134876 -0.094569
# o_dreb -0.385275  0.801985  0.790590  0.636133  0.571887  0.318572  0.325538
# o_reb  -0.325513  0.780338  0.835404  0.640693  0.634165  0.199312  0.220577
# o_asts -0.449623  0.761418  0.649035  0.349177  0.279668  0.404848  0.381515
# ...

# %%
sb.violinplot(data=game_data, x="playoff", y="won")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='won'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_pts")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_pts'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_fgm")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_fgm'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_ftm")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_ftm'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_3pm")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_3pm'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_asts")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_asts'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_dreb")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_dreb'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_oreb")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_oreb'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_reb")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_reb'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_stl")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_stl'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_blk")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_blk'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_to")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_to'>

# %%
sb.violinplot(data=game_data, x="playoff", y="o_pf")
# Out:
# <AxesSubplot:xlabel='playoff', ylabel='o_pf'>

# %%
# Select and rename ingame stats (relevant stats for the prediction)
columns_to_add = ['tmID', 'playoff', 'o_fgm', 'o_fga', 'o_ftm', 'o_fta', 'o_3pm', 'o_3pa', 'o_oreb', 'o_dreb', 'o_reb', 'o_asts', 'o_pf', 'o_stl', 'o_to', 'o_blk', 'o_pts', 'd_fgm', 'd_fga', 'd_ftm', 'd_fta', 'd_3pm', 'd_3pa', 'd_oreb', 'd_dreb', 'd_reb', 'd_asts', 'd_pf', 'd_stl', 'd_to', 'd_blk', 'd_pts']
columns_name_mapping_s1 = {'tmID': 'tmID', 'playoff': 'playoff_s1', 'o_fgm' : 'o_fgm_s1', 'o_fga' : 'o_fga_s1', 'o_ftm' : 'o_ftm_s1', 'o_fta' : 'o_fta_s1', 'o_3pm' : 'o_3pm_s1', 'o_3pa' : 'o_3pa_s1', 'o_oreb' : 'o_oreb_s1', 'o_dreb' : 'o_dreb_s1', 'o_reb' : 'o_reb_s1', 'o_asts' : 'o_asts_s1', 'o_pf' : 'o_pf_s1', 'o_stl' : 'o_stl_s1', 'o_to' : 'o_to_s1', 'o_blk' : 'o_blk_s1', 'o_pts' : 'o_pts_s1', 'd_fgm' : 'd_fgm_s1', 'd_fga' : 'd_fga_s1', 'd_ftm' : 'd_ftm_s1', 'd_fta' : 'd_fta_s1', 'd_3pm' : 'd_3pm_s1', 'd_3pa' : 'd_3pa_s1', 'd_oreb' : 'd_oreb_s1', 'd_dreb' : 'd_dreb_s1', 'd_reb' : 'd_reb_s1', 'd_asts' : 'd_asts_s1', 'd_pf' : 'd_pf_s1', 'd_stl' : 'd_stl_s1', 'd_to' : 'd_to_s1', 'd_blk' : 'd_blk_s1', 'd_pts' : 'd_pts_s1'}
columns_name_mapping_s2 = {'tmID': 'tmID', 'playoff': 'playoff_s2', 'o_fgm' : 'o_fgm_s2', 'o_fga' : 'o_fga_s2', 'o_ftm' : 'o_ftm_s2', 'o_fta' : 'o_fta_s2', 'o_3pm' : 'o_3pm_s2', 'o_3pa' : 'o_3pa_s2', 'o_oreb' : 'o_oreb_s2', 'o_dreb' : 'o_dreb_s2', 'o_reb' : 'o_reb_s2', 'o_asts' : 'o_asts_s2', 'o_pf' : 'o_pf_s2', 'o_stl' : 'o_stl_s2', 'o_to' : 'o_to_s2', 'o_blk' : 'o_blk_s2', 'o_pts' : 'o_pts_s2', 'd_fgm' : 'd_fgm_s2', 'd_fga' : 'd_fga_s2', 'd_ftm' : 'd_ftm_s2', 'd_fta' : 'd_fta_s2', 'd_3pm' : 'd_3pm_s2', 'd_3pa' : 'd_3pa_s2', 'd_oreb' : 'd_oreb_s2', 'd_dreb' : 'd_dreb_s2', 'd_reb' : 'd_reb_s2', 'd_asts' : 'd_asts_s2', 'd_pf' : 'd_pf_s2', 'd_stl' : 'd_stl_s2', 'd_to' : 'd_to_s2', 'd_blk' : 'd_blk_s2', 'd_pts' : 'd_pts_s2'}

# Create df to serve as training - season 3 prediction
season3_predicton_df = pd.DataFrame()
year3_playoff = teams_data.loc[teams_data['year'] == 3, ['tmID', 'playoff']]
season3_predicton_df[['tmID', 'predicted_playoff_qualification']] = year3_playoff.values

# Add penultimate season stats to df
year1_stats = teams_data[teams_data['year'] == 1][columns_to_add]
season3_predicton_df = pd.merge(season3_predicton_df, year1_stats, on='tmID', how='inner')
season3_predicton_df = season3_predicton_df.rename(columns=columns_name_mapping_s1)

# Add last season stats to df
year2_stats = teams_data[teams_data['year'] == 2][columns_to_add]
season3_predicton_df = pd.merge(season3_predicton_df, year2_stats, on='tmID', how='inner')
season3_predicton_df = season3_predicton_df.rename(columns=columns_name_mapping_s2)
print(season3_predicton_df)
# Out:
#    tmID predicted_playoff_qualification playoff_s1  o_fgm_s1  o_fga_s1  \
# 0   CHA                               Y          N       812      1903
# 1   CLE                               N          Y       809      1828
# 2   DET                               N          N       868      1980
# 3   HOU                               Y          Y       891      1894
# 4   IND                               Y          N       796      1838
# 5   LAS                               Y          Y       861      1956
# 6   MIA                               N          N       647      1774
# 7   MIN                               N          N       770      1831
# 8   NYL                               Y          Y       792      1815
# 9   ORL                               N          Y       833      1911
# 10  PHO                               N          Y       803      1800
# 11  POR                               N          N       761      1828
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance
label_encoder = LabelEncoder()

# Apply label encoding to the 'tmID' column
season3_predicton_df['tmID'] = label_encoder.fit_transform(season3_predicton_df['tmID'])

season3_predicton_df['predicted_playoff_qualification'] = label_encoder.fit_transform(season3_predicton_df['predicted_playoff_qualification'])

season3_predicton_df['playoff_s1'] = label_encoder.fit_transform(season3_predicton_df['playoff_s1'])

season3_predicton_df['playoff_s2'] = label_encoder.fit_transform(season3_predicton_df['playoff_s2'])

print(season3_predicton_df)
# Out:
#     tmID  predicted_playoff_qualification  playoff_s1  o_fgm_s1  o_fga_s1  \
# 0      0                                1           0       812      1903
# 1      1                                0           1       809      1828
# 2      2                                0           0       868      1980
# 3      3                                1           1       891      1894
# 4      4                                1           0       796      1838
# 5      5                                1           1       861      1956
# 6      6                                0           0       647      1774
# 7      7                                0           0       770      1831
# 8      8                                1           1       792      1815
# 9      9                                0           1       833      1911
# 10    10                                0           1       803      1800
# 11    11                                0           0       761      1828
# ...

# %%
#Data Modelling 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

X=season3_predicton_df.drop(['predicted_playoff_qualification'],axis=1)
y=season3_predicton_df['predicted_playoff_qualification']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=5)

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier
classifier1 = DecisionTreeClassifier()
classifier1.fit(X_train,y_train)
y_pred = classifier1.predict(X_test)

cm_decision_trees = confusion_matrix(y_test,y_pred)
print(cm_decision_trees)

labels = np.unique(y_test)
fig, ax = plt.subplots()
im = ax.imshow(cm_decision_trees, interpolation="nearest", cmap=plt.cm.Blues)
ax.figure.colorbar(im, ax=ax)

# Set labels and title
ax.set(xticks=np.arange(cm_decision_trees.shape[1]),
       yticks=np.arange(cm_decision_trees.shape[0]),
       xticklabels=labels, yticklabels=labels,
       xlabel="Predicted label",
       ylabel="True label",
       title="Decision Trees Confusion Matrix")
plt.xticks(rotation=45, ha="right")

# Loop over data dimensions and create text annotations.
for i in range(cm_decision_trees.shape[0]):
    for j in range(cm_decision_trees.shape[1]):
        ax.text(j, i, format(cm_decision_trees[i, j], "d"),
                ha="center", va="center",
                color="white" if cm_decision_trees[i, j] > cm_decision_trees.max() / 2 else "black")

plt.show()

decision_trees_accuracy = accuracy_score(y_test,y_pred)
print(decision_trees_accuracy)
# Out:
# [[4 0]
#  [0 1]]
# 1.0
